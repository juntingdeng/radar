# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
num_rx = 4
num_tx = 1
start_freq = 77 # GHz
idle_time = 100 # usec
adc_start_time = 6 # usec
ramp_end_time = 63.14 # usec, ramp_end_time = adc_start_time + adc_sample_time(per chirp) + extral_time
chirp_slope =  29.982 # MHz/usec
num_adc_samples = 256
adc_sample_rate = 10 # Msps
num_frames = 256
num_chirps = 204

# %%
t = np.arange(0, ramp_end_time, step=0.5)*1e-6
f = start_freq*1e9 + chirp_slope*1e12*t
print(f[0], f[-1])
sig = np.cos(2*np.pi*f*t)

# plt.plot(t, f)
plt.plot(t, sig)
# Out:
# 77000000000.0 78888866000.0
