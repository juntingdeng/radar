# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
with open('AWR294X_processed_stream_2025_06_04T04_53_41_546.dat', 'rb') as f:
    cont = f.read()
    print(cont)
    try:
          text_data = cont.decode('utf-8')  # Try UTF-8 first
          print(text_data)
    except UnicodeDecodeError:
          try:
              text_data = cont.decode('latin-1')  # Try latin-1 if UTF-8 fails
              print(text_data)
          except UnicodeDecodeError:
              print("Could not decode the file with UTF-8 or latin-1 encoding.")
# Out:
# b'\x02\x01\x04\x03\x06\x05\x08\x07\x01\x00\x07\x04\xe0\x02\x00\x00D)\x00\x00Y\x02\x00\x00\x00\x00\x00\x00\x04\x00\x00\x00\x05\x00\x00\x00\x00\x00\x00\x00\x01\x00\x00\x00@\x00\x00\x00CQ\xc2\xbe\xb2\xb2\x84?\xa1 b\xbc\x00\x00\x00\x004q\xec\xbe*\x0f\x92?\xd2x\x0c\xbd\x00\x00\x00\x00\xe5\xe2\x87>a\xc4\x06@\x15\xd9r=\x00\x00\x00\x00\xa0\xbf|?\xa6\xb2t@VL_=\x00\x00\x00\x00\x07\x00\x00\x00\x10\x00\x00\x00{\x00\xe9\x02\x93\x00\xca\x02\xda\x00\x9b\x02\x91\x00]\x02\x02\x00\x00\x00\x00\x02\x00\x00\xd7\n\xcf\x0bZ\x0c}\x0cK\x0c\xd6\x0c$\r \r\xd1\x0cA\x0c\xde\x0b\xc8\x0bH\x0c\xf1\x0c]\r\x89\r\x83\rP\rx\r\x9d\r\xa4\r{\rG\rF\r@\r\x0b\rX\rT\rW\r\x9c\r\xa9\rl\r\xd8\x0c\x83\x0c\x97\x0c\xfa\x0c\xfc\x0c\xd5\x0c\x9d\x0ci\x0c:\x0c\x19\x0c\xe3\x0b\xa5\x0b7\x0c\xcd\x0c0\rb\r|\r\xc3\r+\x0er\x0e{\x0e;\x0e\xcd\r\xb7\r\x01\x0eH\x0e_\x0e1\x0e\xb0\r\xe7\x0c\x91\x0c\xbe\x0c\x9f\x0cZ\x0c\xf9\x0b\x89\x0b \x0b1\x0b\xc2\x0b\x14\x0c&\x0c\xef\x0b\x8c\x0b\x15\x0b\xe6\n\xf6\n\x12\x0b\x1e\x0b,\x0b%\x0b\xf8\n\xe1\n\x12\x0bH\
# ...
